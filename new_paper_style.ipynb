# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys
import copy
import zipfile
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from PIL import Image
from torchvision import transforms

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
drive_root = "/content/drive/MyDrive"

matches = []
for root, dirs, files in os.walk(drive_root):
    needed = {
        "build_net.py",
        "data_feed.py",
        "main_beam.py",
        "scenario23_img_beam_train.csv",
        "scenario23_img_beam_val.csv",
        "scenario23_img_beam_test.csv",
    }
    if needed.issubset(set(files)):
        matches.append(root)

print("Candidate AUTHOR_ROOT folders:")
for m in matches:
    print(m)
# Out:
# Candidate AUTHOR_ROOT folders:
# /content/drive/MyDrive/Image beam

# %%
AUTHOR_ROOT = "/content/drive/MyDrive/Image beam"   # adjust if needed

print("AUTHOR_ROOT exists:", os.path.exists(AUTHOR_ROOT), AUTHOR_ROOT)
print("build_net.py:", os.path.exists(os.path.join(AUTHOR_ROOT, "build_net.py")))
print("data_feed.py:", os.path.exists(os.path.join(AUTHOR_ROOT, "data_feed.py")))
print("main_beam.py:", os.path.exists(os.path.join(AUTHOR_ROOT, "main_beam.py")))
print("train csv:", os.path.exists(os.path.join(AUTHOR_ROOT, "scenario23_img_beam_train.csv")))
print("val csv  :", os.path.exists(os.path.join(AUTHOR_ROOT, "scenario23_img_beam_val.csv")))
print("test csv :", os.path.exists(os.path.join(AUTHOR_ROOT, "scenario23_img_beam_test.csv")))
# Out:
# AUTHOR_ROOT exists: True /content/drive/MyDrive/Image beam
# build_net.py: True
# data_feed.py: True
# main_beam.py: True
# train csv: True
# val csv  : True
# test csv : True

# %%
ZIP_PATH = "/content/drive/MyDrive/scenario23_dev_w_resources.zip"   # replace this
print("ZIP exists:", os.path.exists(ZIP_PATH), ZIP_PATH)
# Out:
# ZIP exists: True /content/drive/MyDrive/scenario23_dev_w_resources.zip

# %%
EXTRACT_ROOT = "/content/dataset"
os.makedirs(EXTRACT_ROOT, exist_ok=True)

with zipfile.ZipFile(ZIP_PATH, "r") as z:
    z.extractall(EXTRACT_ROOT)

print("Unzip done")
