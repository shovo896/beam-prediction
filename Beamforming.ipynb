# %% [markdown]
# # **Sensing-Aided Beam Prediction**
#
# **Beam selection is a challenge:** Current and future communication systems are moving to higher frequency bands (mmWave in 5G and potentially sub-terahertz in 6G and beyond). The large available bandwidth at the high frequency bands enables these systems to satisfy the increasing data rate demands of the emerging applications, such as autonomous driving, edge computing, and mixed-reality. These systems, however, require deploying large antenna arrays at the transmitters and/or receivers and using narrow beams to guarantee sufficient receiver power. Finding the best beams (out of a pre-defined codebook) at the transmitter and receiver is associated with high beam training overhead (search time to find/align the best beams), which makes it difficult for these systems to support highly-mobile and latency-sensitive applications.
#
#
# **Sensing aided beam prediction** is a promising solution: The dependence of mmWave/ THz communication systems on the LOS links between the transmitter/receiver means that the awareness about their locations and the surrounding environment (geometry of the buildings, moving scatterers, etc.) could potentially help the beam selection process. To that end, the sensing information of the environment and the UE could be utilized to guide the beam management and reduce beam training overhead significantly. For example, the sensory data collected by the RGB cameras, LiDAR, Radars, GPS receivers, etc., can enable the transmitter/receiver decide on where to point their beams (or at least narrow down the candidate beam steering directions).
#
# **Towards real-world deployment:** Recent work on sensing-aided beam prediction has shown initial promising results in utilizing the sensory data such as RGB images, LiDAR, radar and GPS positions for the beam prediction problem. However, these solutions were mainly trained and tested on the same (mainly synthetic) datasets. To take these interesting ideas one step towards real-world deployments, we need to answer the following important question: Can sensing-aided beam prediction solutions perform well on real-world data?

# %% [markdown]
# ![deepsense_overview_v2.png](data:image/png;base64,...)

# %% [markdown]
# ![DeepSense_workshop_info.png](data:image/png;base64,...)

# %% [markdown]
# ![DeepSense_workshop_steps.png](data:image/png;base64,...)

# %% [markdown]
# # **Step 1: Dataset Download and Extraction**
# - URL Assignment:
#   The URLs for the datasets are stored in variables `scenario1` and `scenario2`. This organization makes it easy to reference them later and keeps the download commands clean and understandable.
#
# - Downloading Datasets:
#   The `wget` command downloads files directly from the specified URLs. The `-O` option specifies the output filename, helping identify files related to specific scenarios. The use of Python's f-string format dynamically inserts the URL stored in the variable into the command, ensuring the download command is accurate and easy to modify.
#
#
# - Setup for Extraction:
#   The `zip_lst` array holds the names of the downloaded zip files. This list approach allows for easy expansion if more scenarios are added in the future.
#   `extraction_path` specifies the directory where all files will be extracted, centralizing the extracted data and simplifying access for subsequent analysis or processing steps.
#
# - Extraction Process:
#   The script checks if the extraction directory exists and creates it if it doesn't, ensuring the extraction process won't fail due to a missing directory.
#   It then iterates over each zip file, extracts its contents into the designated directory, and prints out a message indicating which file is currently being extracted. This provides clear feedback to the user about the progress of the extraction process.

# %%
# Use wget to download the datasets from the provided URLs
# !wget -q -O scenario.zip "https://www.dropbox.com/scl/fi/6yz9i95wqbo4czhm8vfme/scenario23_dev_w_resources.zip?rlkey=5du3wqt926wjw6b91qy1d79bj&st=tiflv16w&dl=0"

# %%
import os
import zipfile


# List of zip files to be extracted
zip_lst = ['scenario.zip']
# Path where the extracted contents will be stored
extraction_path = './dataset'

# Ensure the extraction directory exists
os.makedirs(extraction_path, exist_ok=True)

# Loop through each zip file in the list and extract it
for zip_path in zip_lst:
    print(f"Extracting {zip_path}")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extraction_path)

print("Extraction complete!")
# Out:
# Extracting scenario.zip
# Extraction complete!

# %% [markdown]
# **Download Pre-Trained Models**

# %%
# !wget -q -O checkpoint.zip "https://www.dropbox.com/scl/fi/6yz9i95wqbo4czhm8vfme/scenario23_dev_w_resources.zip?rlkey=5du3wqt926wjw6b91qy1d79bj&st=tiflv16w&dl=0https://www.dropbox.com/scl/fi/6yz9i95wqbo4czhm8vfme/scenario23_dev_w_resources.zip?rlkey=5du3wqt926wjw6b91qy1d79bj&st=tiflv16w&dl=0"
# !unzip checkpoint.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5400_17_14_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5401_17_14_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5402_17_14_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5403_17_14_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5404_17_14_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5405_17_14_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5406_17_14_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5407_17_14_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5408_17_14_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5409_17_14_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_540_16_59_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5410_17_14_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5411_17_14_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5412_17_14_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5413_17_14_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5414_17_14_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5415_17_14_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5416_17_14_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5417_17_14_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5418_17_14_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5419_17_14_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_541_16_59_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5420_17_14_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5421_17_14_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5422_17_14_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5423_17_14_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5424_17_14_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5425_17_14_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5426_17_14_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5427_17_14_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5428_17_14_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5429_17_14_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_542_16_59_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5430_17_14_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5431_17_14_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5432_17_14_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5433_17_14_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5434_17_14_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5435_17_14_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5436_17_14_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5437_17_14_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5438_17_14_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5439_17_14_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_543_16_59_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5440_17_14_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5441_17_14_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5442_17_14_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5443_17_14_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5444_17_14_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5445_17_14_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5446_17_14_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5447_17_14_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5448_17_14_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5449_17_14_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_544_16_59_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5450_17_14_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5451_17_14_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5452_17_14_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5453_17_14_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5454_17_14_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5455_17_14_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5456_17_14_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5457_17_14_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5458_17_14_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5459_17_14_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_555_16_59_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5560_17_15_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5561_17_15_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5562_17_15_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5563_17_15_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5564_17_15_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5565_17_15_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5566_17_15_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5567_17_15_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5568_17_15_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5569_17_15_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_557_16_59_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5660_17_15_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5661_17_15_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5662_17_15_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5663_17_15_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5664_17_15_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5665_17_15_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5666_17_15_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5667_17_15_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_556_16_59_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5570_17_15_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5571_17_15_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5572_17_15_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5573_17_15_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5574_17_15_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5575_17_15_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5576_17_15_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5577_17_15_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5578_17_15_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5579_17_15_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5580_17_15_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5581_17_15_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5582_17_15_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5583_17_15_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5584_17_15_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5585_17_15_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5586_17_15_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5587_17_15_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5588_17_15_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5589_17_15_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_558_16_59_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5590_17_15_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5591_17_15_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5592_17_15_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5593_17_15_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5594_17_15_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5595_17_15_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5596_17_15_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5597_17_15_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5598_17_15_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5599_17_15_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_559_16_59_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_55_16_58_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5600_17_15_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5601_17_15_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5602_17_15_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5603_17_15_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5604_17_15_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5605_17_15_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5606_17_15_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5607_17_15_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5608_17_15_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5609_17_15_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_560_16_59_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5610_17_15_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5611_17_15_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5612_17_15_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5613_17_15_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5614_17_15_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5615_17_15_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5616_17_15_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5617_17_15_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5618_17_15_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5619_17_15_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_561_16_59_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5620_17_15_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5621_17_15_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5622_17_15_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5623_17_15_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5624_17_15_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5625_17_15_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5626_17_15_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5627_17_15_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5628_17_15_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5629_17_15_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_562_16_59_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5630_17_15_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5631_17_15_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5632_17_15_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5633_17_15_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5634_17_15_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5635_17_15_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5636_17_15_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5637_17_15_27.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5638_17_15_27.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5639_17_15_27.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_563_16_59_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5640_17_15_27.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5641_17_15_27.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5642_17_15_27.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5643_17_15_27.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5644_17_15_27.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5645_17_15_28.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5646_17_15_28.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5647_17_15_29.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5648_17_15_30.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5649_17_15_30.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_564_16_59_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5650_17_15_30.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5651_17_15_30.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5652_17_15_30.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5653_17_15_30.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5654_17_15_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5655_17_15_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5656_17_15_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5657_17_15_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5658_17_15_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5659_17_15_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_565_16_59_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5668_17_15_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5669_17_15_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_566_16_59_59.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5670_17_15_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5671_17_15_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5672_17_15_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5673_17_15_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5674_17_15_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5675_17_15_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5676_17_15_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5677_17_15_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5678_17_15_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5679_17_15_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_576_17_00_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5770_17_15_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5771_17_15_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5772_17_15_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5773_17_15_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5774_17_15_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5775_17_15_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5776_17_15_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5777_17_15_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_567_16_59_59.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5680_17_15_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5681_17_15_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5682_17_15_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5683_17_15_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5684_17_15_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5685_17_15_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5686_17_15_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5687_17_15_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5688_17_15_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5689_17_15_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_568_17_00_00.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5690_17_15_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5691_17_15_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5692_17_15_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5693_17_15_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5694_17_15_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5695_17_15_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5696_17_15_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5697_17_15_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5698_17_15_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5699_17_15_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_569_17_00_00.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_56_16_58_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5700_17_15_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5701_17_15_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5702_17_15_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5703_17_15_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5704_17_15_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5705_17_15_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5706_17_15_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5707_17_15_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5708_17_15_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5709_17_15_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_570_17_00_00.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5710_17_15_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5711_17_15_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5712_17_15_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5713_17_15_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5714_17_15_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5715_17_15_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5716_17_15_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5717_17_15_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5718_17_15_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5719_17_15_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_571_17_00_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5720_17_15_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5721_17_15_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5722_17_15_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5723_17_15_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5724_17_15_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5725_17_15_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5726_17_15_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5727_17_15_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5728_17_15_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5729_17_15_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_572_17_00_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5730_17_15_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5731_17_15_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5732_17_15_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5733_17_15_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5734_17_15_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5735_17_15_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5736_17_15_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5737_17_15_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5738_17_15_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5739_17_15_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_573_17_00_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5740_17_15_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5741_17_15_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5742_17_15_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5743_17_15_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5744_17_15_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5745_17_15_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5746_17_15_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5747_17_15_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5748_17_15_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5749_17_15_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_574_17_00_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5750_17_15_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5751_17_15_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5752_17_15_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5753_17_15_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5754_17_15_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5755_17_15_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5756_17_15_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5757_17_15_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5758_17_15_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5759_17_15_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_575_17_00_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5760_17_15_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5761_17_15_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5762_17_15_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5763_17_15_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5764_17_15_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5765_17_15_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5766_17_15_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5767_17_15_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5768_17_15_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5769_17_15_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5778_17_15_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5869_17_16_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_586_17_00_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5870_17_16_10.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5871_17_16_11.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5872_17_16_11.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5873_17_16_11.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5874_17_16_11.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5875_17_16_11.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5876_17_16_12.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5877_17_16_12.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5779_17_15_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_577_17_00_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5780_17_15_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5781_17_15_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5782_17_15_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5783_17_15_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5784_17_15_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5785_17_15_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5786_17_15_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5787_17_15_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5788_17_15_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5789_17_15_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_578_17_00_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5790_17_15_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5791_17_15_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5792_17_15_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5793_17_15_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5794_17_15_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5795_17_15_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5796_17_15_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5797_17_15_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5798_17_15_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5799_17_15_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_579_17_00_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_57_16_58_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5800_17_15_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5801_17_15_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5802_17_15_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5803_17_15_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5804_17_15_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5805_17_15_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5806_17_15_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5807_17_15_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5808_17_15_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5809_17_15_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_580_17_00_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5810_17_15_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5811_17_15_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5812_17_15_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5813_17_15_56.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5814_17_15_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5815_17_15_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5816_17_15_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5817_17_15_57.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5818_17_15_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5819_17_15_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_581_17_00_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5820_17_15_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5821_17_15_58.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5822_17_15_59.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5823_17_15_59.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5824_17_15_59.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5825_17_15_59.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5826_17_16_00.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5827_17_16_00.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5828_17_16_00.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5829_17_16_00.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_582_17_00_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5830_17_16_00.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5831_17_16_00.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5832_17_16_00.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5833_17_16_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5834_17_16_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5835_17_16_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5836_17_16_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5837_17_16_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5838_17_16_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5839_17_16_01.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_583_17_00_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5840_17_16_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5841_17_16_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5842_17_16_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5843_17_16_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5844_17_16_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5845_17_16_06.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5846_17_16_06.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5847_17_16_06.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5848_17_16_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5849_17_16_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_584_17_00_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5850_17_16_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5851_17_16_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5852_17_16_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5853_17_16_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5854_17_16_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5855_17_16_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5856_17_16_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5857_17_16_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5858_17_16_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5859_17_16_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_585_17_00_02.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5860_17_16_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5861_17_16_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5862_17_16_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5863_17_16_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5864_17_16_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5865_17_16_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5866_17_16_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5867_17_16_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5868_17_16_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5878_17_16_12.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5879_17_16_12.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_596_17_00_04.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_587_17_00_03.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5880_17_16_12.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5881_17_16_12.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5882_17_16_12.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5883_17_16_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5884_17_16_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5885_17_16_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5886_17_16_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5887_17_16_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5888_17_16_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5889_17_16_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_588_17_00_03.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5890_17_16_13.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5891_17_16_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5892_17_16_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5893_17_16_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5894_17_16_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5895_17_16_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5896_17_16_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5897_17_16_14.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5898_17_16_15.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5899_17_16_15.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_589_17_00_03.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_58_16_58_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5900_17_16_15.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5901_17_16_15.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5902_17_16_15.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5903_17_16_15.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5904_17_16_15.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5905_17_16_16.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5906_17_16_16.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5907_17_16_16.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5908_17_16_16.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5909_17_16_16.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_590_17_00_03.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5910_17_16_16.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5911_17_16_16.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5912_17_16_16.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5913_17_16_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5914_17_16_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5915_17_16_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5916_17_16_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5917_17_16_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5918_17_16_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5919_17_16_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_591_17_00_03.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5920_17_16_17.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5921_17_16_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5922_17_16_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5923_17_16_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5924_17_16_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5925_17_16_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5926_17_16_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5927_17_16_18.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5928_17_16_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5929_17_16_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_592_17_00_03.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5930_17_16_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5931_17_16_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5932_17_16_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5933_17_16_19.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5934_17_16_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5935_17_16_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5936_17_16_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5937_17_16_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5938_17_16_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5939_17_16_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_593_17_00_03.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5940_17_16_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5941_17_16_20.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5942_17_16_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5943_17_16_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5944_17_16_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5945_17_16_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5946_17_16_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5947_17_16_21.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5948_17_16_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5949_17_16_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_594_17_00_03.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5950_17_16_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5951_17_16_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5952_17_16_22.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5953_17_16_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5954_17_16_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5955_17_16_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5956_17_16_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5957_17_16_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5958_17_16_23.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5959_17_16_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_595_17_00_04.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5960_17_16_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5961_17_16_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5962_17_16_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5963_17_16_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5964_17_16_24.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5965_17_16_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5966_17_16_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5967_17_16_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5968_17_16_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5969_17_16_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5970_17_16_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5976_17_16_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5971_17_16_25.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5977_17_16_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5972_17_16_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5973_17_16_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_5974_17_16_26.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6156_17_44_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6157_17_44_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6158_17_44_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6159_17_44_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_615_17_00_06.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6160_17_44_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6161_17_44_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6162_17_44_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6163_17_44_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6164_17_44_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6165_17_44_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6166_17_44_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6167_17_44_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6168_17_44_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6169_17_44_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_616_17_00_06.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6170_17_44_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6171_17_44_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6172_17_44_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6173_17_44_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6174_17_44_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6175_17_44_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6176_17_44_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6177_17_44_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6178_17_44_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6179_17_44_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_617_17_00_06.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6180_17_44_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6181_17_44_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_6182_17_44_43.txt
# ...
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_978_17_01_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9790_17_55_30.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9791_17_55_30.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9792_17_55_30.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9793_17_55_30.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9794_17_55_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9795_17_55_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9796_17_55_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9797_17_55_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9798_17_55_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9799_17_55_31.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_979_17_01_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_97_16_58_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9800_17_55_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9801_17_55_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9802_17_55_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9803_17_55_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9804_17_55_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9805_17_55_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9806_17_55_32.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9807_17_55_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9808_17_55_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9809_17_55_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_980_17_01_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9810_17_55_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9811_17_55_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9812_17_55_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9813_17_55_33.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9814_17_55_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9815_17_55_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9816_17_55_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9817_17_55_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9818_17_55_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9819_17_55_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_981_17_01_07.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9820_17_55_34.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9821_17_55_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9822_17_55_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9823_17_55_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9824_17_55_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9825_17_55_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9826_17_55_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9827_17_55_35.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9828_17_55_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9829_17_55_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_982_17_01_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9830_17_55_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9831_17_55_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9832_17_55_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9833_17_55_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9834_17_55_36.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9835_17_55_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9836_17_55_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9837_17_55_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9838_17_55_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9839_17_55_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_983_17_01_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9840_17_55_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9841_17_55_37.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9842_17_55_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9843_17_55_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9844_17_55_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9845_17_55_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9846_17_55_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9847_17_55_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9848_17_55_38.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9849_17_55_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_984_17_01_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9850_17_55_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9851_17_55_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9852_17_55_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9853_17_55_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9854_17_55_39.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9855_17_55_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9856_17_55_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9857_17_55_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9858_17_55_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9859_17_55_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_985_17_01_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9860_17_55_40.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9861_17_55_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9862_17_55_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9863_17_55_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9864_17_55_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9865_17_55_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9866_17_55_41.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9867_17_55_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9868_17_55_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9869_17_55_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_986_17_01_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9870_17_55_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9871_17_55_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9872_17_55_42.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9873_17_55_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9874_17_55_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9875_17_55_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9876_17_55_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9877_17_55_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9878_17_55_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9879_17_55_43.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_987_17_01_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9880_17_55_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9881_17_55_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9882_17_55_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9883_17_55_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9884_17_55_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9885_17_55_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9886_17_55_44.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9887_17_55_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9888_17_55_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9889_17_55_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_988_17_01_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9890_17_55_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9891_17_55_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9892_17_55_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9893_17_55_45.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9894_17_55_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9895_17_55_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9896_17_55_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9897_17_55_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9898_17_55_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9899_17_55_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_989_17_01_08.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_98_16_58_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9900_17_55_46.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9901_17_55_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9902_17_55_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9903_17_55_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9904_17_55_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9905_17_55_47.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9906_17_55_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9907_17_55_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9908_17_55_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9909_17_55_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_990_17_01_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9910_17_55_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9911_17_55_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9912_17_55_48.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9913_17_55_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9914_17_55_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9915_17_55_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9916_17_55_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9917_17_55_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9918_17_55_49.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9919_17_55_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_991_17_01_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9920_17_55_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9921_17_55_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9922_17_55_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9923_17_55_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9924_17_55_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9925_17_55_50.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9926_17_55_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9927_17_55_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9928_17_55_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9929_17_55_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_992_17_01_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9930_17_55_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9931_17_55_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9932_17_55_51.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9933_17_55_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9934_17_55_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9935_17_55_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9936_17_55_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9937_17_55_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9938_17_55_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9939_17_55_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_993_17_01_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9940_17_55_52.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9941_17_55_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9942_17_55_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9943_17_55_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9944_17_55_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9945_17_55_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9946_17_55_53.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9947_17_55_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9948_17_55_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9949_17_55_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_994_17_01_09.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9950_17_55_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9951_17_55_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9952_17_55_54.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9953_17_55_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9954_17_55_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9955_17_55_55.txt
#   inflating: scenario23_dev/resources/bbox_labels_final/image_BS1_9956_17_55_55.txt

# %% [markdown]
# # **Step 2: Task-Specific Data Preparation**
#
# After downloading and extracting the datasets, the next stage is to prepare different subsets of the data tailored for specific machine learning tasks. This involves reading the extracted data, processing it according to the requirements of each task, and then organizing it into structured formats suitable for training machine learning models. The following cells will guide you through this process, detailing each step to ensure clarity and comprehension.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What does this include?**
# Reading the scenario csv file --> Updating the paths to the sensing modality --> Normalizing any data (if needed) --> computing the optimal beams (subsample if needed

# %% [markdown]
# **Setups and Imports:**

# %%
import os
import random
import datetime

import numpy as np
import pandas as pd

import torch
from sklearn.utils import shuffle
import matplotlib.pyplot as plt


#from numpy.random import RandomState

# %%
def set_seed(seed=42):
    """Sets the seed for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if using multi-GPU.
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
seed_num = 42
set_seed(seed_num)

# %%
# Get the current working directory
current_path = os.getcwd()


# Define the scenario and set up directory paths
data_root = os.path.join(current_path, 'dataset')
processed_data = os.path.join(current_path, 'task_specific_data')


if not os.path.exists(processed_data):
    os.makedirs(processed_data)

# %%
# Helpers to resolve scenario roots and data files across dataset layouts
def resolve_scenario_paths(scenario_num):
    scenario_csv_name = f'scenario{scenario_num}.csv'
    candidate_dirs = [
        os.path.join(data_root, f'Scenario{scenario_num}'),
        os.path.join(data_root, f'scenario{scenario_num}'),
        os.path.join(data_root, f'scenario{scenario_num}_dev'),
    ]

    for scenario_root in candidate_dirs:
        data_csv = os.path.join(scenario_root, scenario_csv_name)
        if os.path.isfile(data_csv):
            return scenario_root, data_csv

    matches = []
    for root, _, files in os.walk(data_root):
        if scenario_csv_name in files:
            matches.append(os.path.join(root, scenario_csv_name))

    if not matches:
        raise FileNotFoundError(
            f"Could not find {scenario_csv_name} under {data_root}. Check your extracted dataset structure."
        )

    data_csv = matches[0]
    scenario_root = os.path.dirname(data_csv)
    print(f"Using dataset root: {scenario_root}")
    return scenario_root, data_csv

def resolve_data_file(scenario_root, entry):
    relative_path = str(entry).replace('\\', '/').strip()
    if relative_path.startswith('./'):
        relative_path = relative_path[2:]
    return os.path.join(scenario_root, relative_path)

# Function to subsample power data and update beam indices
def subsample_and_update_beams(pwr_data_lst, scenario_path):
    updated_beam, original_beam = [], []

    for entry in pwr_data_lst:
        data_to_read = resolve_data_file(scenario_path, entry)
        pwr_data = np.loadtxt(data_to_read)
        original_beam.append(np.argmax(pwr_data) + 1)
        updated_pwr = pwr_data[::2]  # subsample every other power entry
        updated_beam.append(np.argmax(updated_pwr) + 1)

    return updated_beam, original_beam

# %%
def create_subsampled_dataset(scenario_num):
    scenario_root, data_csv = resolve_scenario_paths(scenario_num)
    print(f"Reading scenario CSV from: {data_csv}")

    # Read the initial dataset
    df = pd.read_csv(data_csv)
    image_data_lst = df['unit1_rgb'].values
    pwr_data_lst = df['unit1_pwr_60ghz'].values


    updated_beam, original_beam = subsample_and_update_beams(pwr_data_lst, scenario_root)
    return updated_beam, original_beam

# %%
def create_img_beam_dataset(scenario_num, seed_num, processed_data_path):

    folder_to_save = f'{processed_data_path}/Scenario{scenario_num}/image_beam'
    if not os.path.exists(folder_to_save):
        os.makedirs(folder_to_save)

    scenario_root, data_csv = resolve_scenario_paths(scenario_num)
    print(data_csv)

    updated_beam, original_beam = create_subsampled_dataset(scenario_num)

    # Read the initial dataset
    df = pd.read_csv(data_csv)
    image_data_lst = df['unit1_rgb'].values
    print(len(image_data_lst))

    #############################################
    ###### created updated image path ###########
    #############################################
    updated_img_path = []
    for entry in image_data_lst:
        updated_path = resolve_data_file(scenario_root, entry)
        #print("updated path", updated_path)
        updated_img_path.append(updated_path)


    #############################################
    # saving the image-beam development dataset for training and validation
    #############################################

    indx = np.arange(1, len(updated_beam)+1,1)
    df_new = pd.DataFrame()
    df_new['index'] = indx
    df_new['unit1_rgb'] = updated_img_path
    df_new['unit1_beam_32'] = updated_beam
    df_new['unit1_beam_64'] = original_beam
    df_new.to_csv(fr'{folder_to_save}/scenario{scenario_num}_image_beam.csv', index=False)

    #############################################
    #generate the train and test dataset
    #############################################
    #rng = RandomState(1)
    train, val, test = np.split(df_new.sample(frac=1, random_state=seed_num ), [int(.6*len(df_new)), int(.9*len(df_new))])
    #train, val, test = np.split(df_new.sample(frac=1), [int(.6*len(df_new)), int(.9*len(df_new))])
    train.to_csv(f'{folder_to_save}/scenario{scenario_num}_image_beam_train.csv', index=False)
    val.to_csv(f'{folder_to_save}/scenario{scenario_num}_image_beam_val.csv', index=False)
    test.to_csv(f'{folder_to_save}/scenario{scenario_num}_image_beam_test.csv', index=False)

# %%
create_img_beam_dataset(23, seed_num, processed_data)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def create_pos_beam_dataset(scenario_num, seed_num, processed_data_path):

    folder_to_save = f'{processed_data_path}/Scenario{scenario_num}/pos_beam'
    if not os.path.exists(folder_to_save):
        os.makedirs(folder_to_save)

    scenario_root, data_csv = resolve_scenario_paths(scenario_num)

    updated_beam, original_beam = create_subsampled_dataset(scenario_num)

    # Read the initial dataset
    df = pd.read_csv(data_csv)
    pwr_data_lst = df['unit1_pwr_60ghz'].values

    ###############################################
    ####### read position values from dataset #####
    ###############################################

    lat = []
    lon = []
    pos_data_path = df['unit2_loc'].values
    for entry in pos_data_path:
        data_to_read = resolve_data_file(scenario_root, entry)
        pos_val = np.loadtxt(data_to_read)
        #lat_val, lon_val = pos_val[0], pos_val[1]
        lat.append(pos_val[0])
        lon.append(pos_val[1])

    def norm_data(data_lst):
        norm_data = []
        for entry in data_lst:
            norm_data.append((entry - min(data_lst))/(max(data_lst) - min(data_lst)))
        return norm_data

    ###############################################
    ##### normalize latitude and longitude data ###
    ###############################################
    lat_norm = norm_data(lat)
    lon_norm = norm_data(lon)

    ###############################################
    ##### generate final pos data #################
    ###############################################
    pos_data = []
    for j in range(len(lat_norm)):
        pos_data.append([lat_norm[j], lon_norm[j]])


    #############################################
    # saving the pos-beam development dataset for training and validation
    #############################################

    indx = np.arange(1, len(updated_beam)+1,1)
    df_new = pd.DataFrame()
    df_new['index'] = indx
    df_new['unit2_pos'] = pos_data
    df_new['unit1_beam_32'] = updated_beam
    df_new['unit1_beam_64'] = original_beam
    df_new.to_csv(fr'{folder_to_save}/scenario{scenario_num}_pos_beam.csv', index=False)

    #############################################
    #generate the train and test dataset
    #############################################
    #rng = RandomState(1)
    train, val, test = np.split(df_new.sample(frac=1, random_state=seed_num ), [int(.6*len(df_new)), int(.9*len(df_new))])
    #train, val, test = np.split(df_new.sample(frac=1), [int(.6*len(df_new)), int(.9*len(df_new))])
    train.to_csv(f'{folder_to_save}/scenario{scenario_num}_pos_beam_train.csv', index=False)
    val.to_csv(f'{folder_to_save}/scenario{scenario_num}_pos_beam_val.csv', index=False)
    test.to_csv(f'{folder_to_save}/scenario{scenario_num}_pos_beam_test.csv', index=False)

# %%
create_pos_beam_dataset(23, seed_num, processed_data)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Step 3: ML Training**
#
# **Directory Setup for Machine Learning Experiments**
# This script is designed to set up and organize directories for saving various outputs and checkpoints related to machine learning experiments. It ensures that all necessary directories exist and are ready for use to store training artifacts, analysis files, and model checkpoints. Here’s a step-by-step explanation of the script’s operations:
#
# **Base Directory Initialization:**
# The variable ML_code is set to /content/ML_code, specifying the root directory intended for all machine learning code and related files.
# If this directory does not exist, it is created using os.makedirs. This ensures that there is a dedicated space in the filesystem to organize and store machine learning project files.
#
# **Timestamp Creation:** The script generates timestamps to uniquely identify each experiment or session. This is done using Python’s datetime module.
#
#
# **Working Directory Setup:**
# A path pwd is constructed combining the base directory, a subfolder named saved_folder, and the current date and time. This path is where all files related to the current session or experiment will be stored.
# The script checks if this directory exists. If not, it creates the directory using os.makedirs.
#
# **Subdirectories for Analysis Files and Checkpoints:**
# Inside the session-specific directory (pwd), additional subdirectories are created:
# * saved_analysis_files: Intended to store output files, logs, figures, or any
# other analysis results.
# * checkpoint: Designated for saving model checkpoints during training, which allows for model recovery and resuming training if necessary.
#
# The existence of each subdirectory is checked. If a directory does not exist, it is created.

# %%
ML_code = os.path.join(current_path, 'ML_code')

if not os.path.exists(ML_code):
    os.makedirs(ML_code)

# year month day
dayTime = datetime.datetime.now().strftime('%m-%d-%Y')
# Minutes and seconds
hourTime = datetime.datetime.now().strftime('%H_%M')
print(dayTime + '\n' + hourTime)

pwd = os.path.join(ML_code, 'saved_folder', f'{dayTime}_{hourTime}')
print(pwd)
# Determine whether the folder already exists
if not os.path.exists(pwd):
    os.makedirs(pwd)

#create folder to save analysis files and checkpoint
save_directory = os.path.join(pwd, 'saved_analysis_files')
checkpoint_directory = os.path.join(pwd, 'checkpoint')

if not os.path.exists(save_directory):
    os.makedirs(save_directory)

if not os.path.exists(checkpoint_directory):
    os.makedirs(checkpoint_directory)

# %% [markdown]
# **AI-Ready Dataset**
#
# This function is designed to handle the preparation of training, validation, and testing datasets for different modalities within a machine learning workflow. It efficiently manages datasets across various scenarios, ensuring that they are properly combined and shuffled according to specified modalities. Here's how it functions:
#
# **Initialization:** The function starts by setting a base path where scenario-specific data is stored. This path is assumed to contain subfolders for different scenarios, each containing datasets split by training, validation, and testing.
#
# **Modality Handling:** It defines a mapping of modalities to their respective folder names (position, vision, vision-position). This mapping helps the function navigate to the correct dataset folder based on the specified modality.
#
# **Scenario Processing:**
#
#
# *   For each scenario number provided, the function constructs the path to the data folder corresponding to the current modality.
# *   It verifies the existence of this folder, skipping the scenario if the folder is not found, thus avoiding errors in attempting to access nonexistent paths.
#
# **Data Aggregation:**
#
#
# *   For each type of dataset (train, validation, test), the function attempts to read CSV files from the respective folders.
# *   These CSV files are then accumulated into separate lists for training, validation, and testing dataframes, depending on their split type.
#
# **Shuffling:**
# After combining all dataframes for each split, the function shuffles them to ensure that the data order does not affect the learning process. This shuffling uses a specified random seed to allow reproducibility of the dataset order across different runs.
#
# **Output:**
# Finally, the function returns three dataframes: one for training, one for validation, and one for testing. Each dataframe is a combination of all corresponding split data from all included scenarios, shuffled and ready for use in training or evaluating a model.

# %%
def combine_shuffle_datasets(train_scenario_nums, test_scenario_nums, modality, percentages=None, seed=42):
    #base_path = '/content/task_specific_data'
    base_path = os.path.join(current_path, 'task_specific_data')

    # DataFrames for each split
    train_dfs = []
    val_dfs = []
    test_dfs = []

    # Supported modalities mapping to their respective folders
    modality_mapping = {
        'position': 'pos_beam',
        'vision': 'image_beam',
        'vision-position': 'img_pos_beam'
    }

    # Check if the provided modality is supported
    if modality not in modality_mapping:
        print(f"Error: Modality '{modality}' is not supported.")
        return None

    # Process each training scenario number
    for i, num in enumerate(train_scenario_nums):
        scenario_folder = f'Scenario{num}'
        full_path = os.path.join(base_path, scenario_folder, modality_mapping[modality])

        # Check if the scenario modality path exists
        if not os.path.exists(full_path):
            print(f"Warning: The path for scenario {num} with modality '{modality}' does not exist. Skipping.")
            continue

        # Handle training data
        train_file_path = os.path.join(full_path, f'scenario{num}_{modality_mapping[modality]}_train.csv')
        if os.path.isfile(train_file_path):
            train_df = pd.read_csv(train_file_path)
            if percentages and percentages[i] < 100:
                train_df = train_df.sample(frac=percentages[i]/100, random_state=seed)
            train_dfs.append(train_df)
        else:
            print(f"Warning: The file {train_file_path} does not exist. Skipping this scenario.")

        # Handle validation data
        val_file_path = os.path.join(full_path, f'scenario{num}_{modality_mapping[modality]}_val.csv')
        if os.path.isfile(val_file_path):
            val_df = pd.read_csv(val_file_path)
            val_dfs.append(val_df)
        else:
            print(f"Warning: The file {val_file_path} does not exist. Skipping this scenario.")

    # Process each testing scenario number
    for num in test_scenario_nums:
        scenario_folder = f'Scenario{num}'
        full_path = os.path.join(base_path, scenario_folder, modality_mapping[modality])

        # Check if the scenario modality path exists
        if not os.path.exists(full_path):
            print(f"Warning: The path for scenario {num} with modality '{modality}' does not exist. Skipping.")
            continue

        # Handle test data
        test_file_path = os.path.join(full_path, f'scenario{num}_{modality_mapping[modality]}_test.csv')
        if os.path.isfile(test_file_path):
            test_df = pd.read_csv(test_file_path)
            test_dfs.append(test_df)
        else:
            print(f"Warning: The file {test_file_path} does not exist. Skipping this scenario.")

    # Concatenate and shuffle the datasets
    train_combined_df = shuffle(pd.concat(train_dfs, ignore_index=True), random_state=seed).reset_index(drop=True)
    val_combined_df = shuffle(pd.concat(val_dfs, ignore_index=True), random_state=seed).reset_index(drop=True)
    test_combined_df = shuffle(pd.concat(test_dfs, ignore_index=True), random_state=seed).reset_index(drop=True)

    return train_combined_df, val_combined_df, test_combined_df

# %%
import torch.cuda as cuda
import torch.optim as optimizer
import torch.nn as nn
import torch.nn.functional as F

import torchvision.models as models
from torchvision import transforms as transforms
from torchsummary import summary
from torch.utils.data import Dataset, DataLoader

from PIL import Image
import torch
import ast

from tqdm import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class CustomDataset(Dataset):
    def __init__(self, dataframe, modality='vision', transform=None):
        """
        Args:
            dataframe (pandas.DataFrame): The dataframe containing the dataset.
            modality (str): Modality to use ('vision', 'position', or 'vision-position').
            transform (callable, optional): Optional transform to be applied on an image.
        """
        self.data = dataframe
        self.modality = modality
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if self.modality in ['vision', 'vision-position']:
            img_path = self.data.loc[idx, 'unit1_rgb']
            image = Image.open(img_path).convert('RGB')
            if self.transform:
                image = self.transform(image)

        if self.modality in ['position', 'vision-position']:
            # Preprocess the string to remove 'np.float64(' and ')'
            pos_str = self.data.loc[idx, 'unit2_pos']
            # Only apply replace if 'np.float64' is found to avoid unnecessary operations
            if 'np.float64' in pos_str:
                pos_str = pos_str.replace('np.float64(', '').replace(')', '')
            position = ast.literal_eval(pos_str)
            position = torch.tensor(position, dtype=torch.float32)

        label = self.data.loc[idx, 'unit1_beam_32'] - 1 # Adjust label to be 0-indexed

        if self.modality == 'vision':
            return image, label
        elif self.modality == 'position':
            return position, label
        elif self.modality == 'vision-position':
            return image, position, label
        else:
            raise ValueError("Invalid modality specified. Choose from 'vision', 'position', or 'vision-position'.")

# %% [markdown]
# **ML Models**

# %% [markdown]
# ![image_pos.png](data:image/png;base64,...)

# %%
# Define the custom model for image input
class CustomImageModel(nn.Module):
    def __init__(self, num_classes):
        super(CustomImageModel, self).__init__()
        # Load a pre-trained ResNet18 model to utilize transfer learning
        ## resnet use koreche ekhbae 
        self.resnet = models.resnet18(pretrained=True)
        # Retrieve the number of input features to the fully connected layer
        num_ftrs = self.resnet.fc.in_features
        # Modify the fully connected layer to match the number of target classes
        self.resnet.fc = nn.Linear(num_ftrs, num_classes)

    def forward(self, image):
        # Perform a forward pass through the modified ResNet18 model with the image as input
        return self.resnet(image)

# Define the custom model for position input
class CustomPositionModel(nn.Module):
    def __init__(self, num_classes, layer_sizes=[64, 128, 64], dropout_prob=0.3):
        super(CustomPositionModel, self).__init__()
        # Initialize module lists to store layers, batch normalization, and dropout layers
        self.layers = nn.ModuleList()
        self.batch_norms = nn.ModuleList()
        self.dropouts = nn.ModuleList()

        # Set the initial input size (e.g., for a 2D position vector)
        input_size = 2
        for size in layer_sizes:
            # Append linear layers, batch normalization, and dropout layers
            self.layers.append(nn.Linear(input_size, size))
            self.batch_norms.append(nn.BatchNorm1d(size))
            self.dropouts.append(nn.Dropout(dropout_prob))
            input_size = size

        # Define the output layer to map the final layer size to the number of classes
        self.output = nn.Linear(layer_sizes[-1], num_classes)

    def forward(self, x):
        # Sequentially apply layers with LeakyReLU activation, followed by batch normalization and dropout
        for layer, norm, dropout in zip(self.layers, self.batch_norms, self.dropouts):
            x = F.leaky_relu(layer(x))
            x = norm(x)
            x = dropout(x)

        # Return the output of the final layer
        return self.output(x)

# Define the custom model for image and position combined input
class CustomImagePositionModel(nn.Module):
    def __init__(self, num_classes):
        super(CustomImagePositionModel, self).__init__()
        # Load a pre-trained ResNet18 model without the final fully connected layer
        self.resnet = models.resnet18(pretrained=True)
        self.resnet = nn.Sequential(*list(self.resnet.children())[:-1])
        # Define the fully connected layer to handle combined features from image and position
        self.fc = nn.Linear(512 + 2, num_classes)  # 512 for image features from ResNet, 2 for position

    def forward(self, image, position):
        # Extract image features using ResNet
        image_features = self.resnet(image)
        # Flatten the features to prepare for concatenation
        image_features = image_features.view(image_features.size(0), -1)
        # Concatenate image and position features
        concatenated_features = torch.cat((image_features, position), dim=1)
        # Output the result of the fully connected layer
        output = self.fc(concatenated_features)
        return output

# %%
# Factory function to get the model
def get_model(modality, num_classes=None, num_features=None, num_output=None):
    if modality == 'vision':
        if num_classes is None:
            raise ValueError("num_classes must be specified for image modality")
        return CustomImageModel(num_classes=num_classes)
    elif modality == 'position':
        if num_classes is None:
            raise ValueError("num_classes must be specified for position modality")
        return CustomPositionModel(num_classes=num_classes)
    elif modality == 'vision-position':
        if num_classes is None:
            raise ValueError("num_classes must be specified for image-position modality")
        return CustomImagePositionModel(num_classes=num_classes)
    else:
        raise ValueError(f"Unknown modality: {modality}")

# %%
# Enhanced transformation pipeline with data augmentation for training
train_transforms = transforms.Compose([
    transforms.Resize((256, 256)),            # Resize to a slightly larger square
    transforms.RandomCrop((224, 224)),        # Randomly crop to 224x224
    transforms.RandomHorizontalFlip(),        # Randomly flip the images horizontally
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),  # Randomly alter the color properties
    transforms.ToTensor(),                    # Convert images to tensors
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))  # Normalize the images
])

# Validation and test transformations can be less aggressive since we're not training on this data
test_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize the images to 224x224
    transforms.ToTensor(),          # Convert images to tensors
    transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))  # Normalize the images
])

# %%
# Factory function to get the model
def get_model(modality, num_classes=None, num_features=None, num_output=None):
    if modality == 'vision':
        if num_classes is None:
            raise ValueError("num_classes must be specified for image modality")
        return CustomImageModel(num_classes=num_classes)
    elif modality == 'position':
        if num_classes is None:
            raise ValueError("num_classes must be specified for position modality")
        return CustomPositionModel(num_classes=num_classes)
    elif modality == 'vision-position':
        if num_classes is None:
            raise ValueError("num_classes must be specified for image-position modality")
        return CustomImagePositionModel(num_classes=num_classes)
    else:
        raise ValueError(f"Unknown modality: {modality}")

# %%
def train(model, train_loader, criterion, optimizer, device, modality):
    model.train()
    running_loss = 0
    for data in tqdm(train_loader, desc="Training"):
        optimizer.zero_grad()
        if modality == 'vision-position':
            img, pos, label = data
            img, pos, label = img.to(device), pos.to(device), label.to(device)
            outputs = model(img, pos)
        else:
            inputs, label = data
            inputs, label = inputs.to(device), label.to(device)
            outputs = model(inputs)

        loss = criterion(outputs, label)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    average_loss = running_loss / len(train_loader)
    print(f'Average Training Loss: {average_loss}')
    return average_loss

# %%
def validate(model, val_loader, device, modality):
    model.eval()
    top1_acc, top2_acc, top3_acc = 0, 0, 0
    total_count = 0
    results = {'top1_pred': [], 'top2_pred': [], 'top3_pred': [], 'labels': []}
    with torch.no_grad():
        for data in tqdm(val_loader, desc="Validation"):
            if modality == 'vision-position':
                imgs, pos, labels = data
                imgs, pos, labels = imgs.to(device), pos.to(device), labels.to(device)
                outputs = model(imgs, pos)
            else:
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)

            _, top1_pred = torch.max(outputs, 1)
            sorted_out = torch.argsort(outputs, dim=1, descending=True)
            results['labels'].extend(labels.cpu().numpy().tolist())
            results['top1_pred'].extend(top1_pred.cpu().numpy().tolist())
            results['top2_pred'].extend(sorted_out[:, :2].cpu().numpy().tolist())
            results['top3_pred'].extend(sorted_out[:, :3].cpu().numpy().tolist())
            top1_acc += torch.sum(top1_pred == labels).item()
            top2_acc += torch.sum(sorted_out[:, :2] == labels.unsqueeze(1)).sum().item()
            top3_acc += torch.sum(sorted_out[:, :3] == labels.unsqueeze(1)).sum().item()
            total_count += labels.size(0)
    print(f'Validation Accuracy - Top1: {top1_acc / total_count}, Top2: {top2_acc / total_count}, Top3: {top3_acc / total_count}')
    return top1_acc / total_count, top2_acc / total_count, top3_acc / total_count, results

# %%
def log_and_save_results(results, save_directory, epoch):
    os.makedirs(save_directory, exist_ok=True)
    file_name = f'top_pred_beam_epoch_{epoch+1}.csv'
    file_to_save = os.path.join(save_directory, file_name)
    df = pd.DataFrame(results)
    df.to_csv(file_to_save, index=False)
    print(f"Results saved to {file_to_save}")

# %%
def main_training_loop(train_df, val_df, test_df, device, modality, batch_size=64):

    model = get_model(modality, num_classes=65)
    model = model.to(device)

    # Example usage:
    #train_df, val_df, test_df = combine_shuffle_datasets([1, 2], modality, seed=seed_num)
    print(train_df.head())  # Display the first few rows of the train, val, and test data

    print(pwd)

    train_df.to_csv(f'{pwd}/train.csv', index=False)
    val_df.to_csv(f'{pwd}/val.csv', index=False)
    test_df.to_csv(f'{pwd}/test.csv', index=False)

    # Set the batch sizes and number of workers
    batch_size = batch_size
    val_batch_size = 1
    num_workers = 2  # Adjust based on the capabilities of your machine

    lr = 1e-4
    decay = 1e-4


    # Create dataset instances for each DataFrame
    train_dataset = CustomDataset(dataframe=train_df, modality=modality, transform=train_transforms)
    val_dataset = CustomDataset(dataframe=val_df, modality=modality, transform=test_transforms)
    test_dataset = CustomDataset(dataframe=test_df, modality=modality, transform=test_transforms)

    # Set up the DataLoader for each dataset
    train_loader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True,  # Shuffle for training to randomize input
                              num_workers=num_workers)

    val_loader = DataLoader(val_dataset,
                            batch_size=val_batch_size,
                            shuffle=False,  # No need to shuffle validation and test data
                            num_workers=num_workers)

    test_loader = DataLoader(test_dataset,
                            batch_size=val_batch_size,
                            shuffle=False,
                            num_workers=num_workers)


    criterion = nn.CrossEntropyLoss()
    opt = optimizer.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
    if modality == 'position':
        scheduler = optimizer.lr_scheduler.MultiStepLR(opt, milestones=[20, 30], gamma=0.1)
        num_epochs = 40
    else:
        scheduler = optimizer.lr_scheduler.MultiStepLR(opt, milestones=[4, 8], gamma=0.1)
        num_epochs = 5

    best_accuracy = 0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch + 1}')
        train(model, train_loader, criterion, opt, device, modality)
        accuracy, _, _, results = validate(model, val_loader, device, modality)
        log_and_save_results(results, save_directory, epoch)

        print("current acc", accuracy)
        print("best acc", best_accuracy)
        if accuracy > best_accuracy:
            print("Saving the best model")
            net_name = checkpoint_directory  + '/' +  f'beam_pred_model_{modality}'
            torch.save(model.state_dict(), net_name)
            best_accuracy =  accuracy
        print("updated best acc", best_accuracy)

        scheduler.step()



    # Load the best checkpoint
    # Assuming the best model's name is preserved in `net_name`, load the best model
    best_model_path = net_name  # This should be the path where the best model is saved
    model.load_state_dict(torch.load(best_model_path))
    model.to(device)  # Ensure model is on the correct device

    print("Model accuracy on the test set")

    # Optionally, evaluate the model to confirm it's loaded correctly and check performance
    model.eval()
    test_accuracy, _, _, test_results = validate(model, test_loader, device, modality)
    #print(f'Loaded Model Accuracy: {accuracy}')
    return model, test_results

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# # **Position Aided Beam Prediction**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
# (Make sure 'ast' or 're' is imported if you use them, though simple string replace doesn't need them)

modality = 'position'

train_scenario_nums = [23]  # Scenarios 1, 2, and 3 will be used for training
test_scenario_nums = [23]      # Scenarios 4 and 5 will be used for testing

# Define the percentage of data to be used from each training scenario
percentages = [30]  # Use 40% of Scenario 1, 40% of Scenario 2, and 40% of Scenario 3

# Run the function to get the DataFrames
train_df, val_df, test_df = combine_shuffle_datasets(train_scenario_nums, test_scenario_nums, modality, percentages)

# ==========================================
# ADD THIS CLEANUP BLOCK HERE
# ==========================================
def clean_np_formatting(text):
    """Removes 'np.float64()' wrappers from strings so literal_eval can parse them."""
    if isinstance(text, str):
        return text.replace('np.float64(', '').replace(')', '')
    return text

# Apply the cleanup to the problematic column in all three datasets
train_df['unit2_pos'] = train_df['unit2_pos'].apply(clean_np_formatting)
val_df['unit2_pos'] = val_df['unit2_pos'].apply(clean_np_formatting)
test_df['unit2_pos'] = test_df['unit2_pos'].apply(clean_np_formatting)
# ==========================================

# Now the DataLoader will be able to parse the strings perfectly
model_pos, results_pos = main_training_loop(train_df, val_df, test_df, device, modality)

# Assuming `results` is returned from `validate`
labels = results_pos['labels']
top1_preds = results_pos['top1_pred']

# Calculate the confusion matrix
cm = confusion_matrix(labels, top1_preds)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
import glob

# Search for the file by name, completely ignoring file extensions
found_files = glob.glob('/content/**/*beam_pred*', recursive=True)

if found_files:
    print("🎯 Found it! Your model is saved here:")
    for f in found_files:
        print(f)
else:
    print("🚨 No files found. The model did not save during training!")

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from torch.utils.data import DataLoader

modality = 'position'

# =====================================================================
# 1. LOAD THE EXACT MODEL WE JUST FOUND
# =====================================================================
# Hardcoding the exact path discovered by our search
best_model_path = '/content/ML_code/saved_folder/03-09-2026_06_39/checkpoint/beam_pred_model_position'

print(f"Loading model from: {best_model_path}")
model_pos = get_model(modality, num_classes=65) # Make sure get_model is defined
model_pos.load_state_dict(torch.load(best_model_path, map_location=device))
model_pos = model_pos.to(device)
model_pos.eval()

# =====================================================================
# 2. PREPARE AND CLEAN THE DATA
# =====================================================================
train_scenario_nums = [23]
test_scenario_nums = [23]
percentages = [30]

# Generate dataframes
train_df_pos, val_df_pos, test_df_pos = combine_shuffle_datasets(train_scenario_nums, test_scenario_nums, modality, percentages)

# Fix the np.float64() string issue so the DataLoader doesn't crash
def clean_np_formatting(text):
    if isinstance(text, str):
        return text.replace('np.float64(', '').replace(')', '')
    return text

# Apply the fix to your test data
test_df_pos['unit2_pos'] = test_df_pos['unit2_pos'].apply(clean_np_formatting)

# =====================================================================
# 3. RUN VALIDATION
# =====================================================================
val_batch_size = 1
num_workers = 2

test_dataset = CustomDataset(dataframe=test_df_pos, modality=modality, transform=test_transforms)

test_loader = DataLoader(test_dataset,
                        batch_size=val_batch_size,
                        shuffle=False,
                        num_workers=num_workers)

print("Running validation loop...")
_, _, _, test_results_pos = validate(model_pos, test_loader, device, modality)

# =====================================================================
# 4. PLOT THE CONFUSION MATRIX
# =====================================================================
labels = test_results_pos['labels']
top1_preds = test_results_pos['top1_pred']

# Calculate the confusion matrix
cm = confusion_matrix(labels, top1_preds)

# Normalize the confusion matrix (with safety check for division by zero)
row_sums = cm.sum(axis=1)[:, np.newaxis]
cm_normalized = np.divide(cm.astype('float'), row_sums, out=np.zeros_like(cm, dtype=float), where=row_sums!=0)

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, cmap='Blues')
plt.title('Confusion Matrix on Test Data')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# # **Vision Aided Beam Prediction**

# %%
modality = 'vision'

train_scenario_nums = [23]  # Scenarios 1, 2, and 3 will be used for training
test_scenario_nums = [23]      # Scenarios 4 and 5 will be used for testing

# Define the percentage of data to be used from each training scenario
percentages = [30]  # Use 40% of Scenario 1, 40% of Scenario 2, and 40% of Scenario 3

# Run the function to get the DataFrames
train_df, val_df, test_df = combine_shuffle_datasets(train_scenario_nums, test_scenario_nums, modality, percentages)

def clean_np_formatting(text):
    """Removes 'np.float64()' wrappers from strings so literal_eval can parse them."""
    if isinstance(text, str):
        return text.replace('np.float64(', '').replace(')', '')
    return text

model_vision, results_vision = main_training_loop(train_df, val_df, test_df, device, modality)

# Assuming `results` is returned from `validate`
labels = results_vision['labels']
top1_preds = results_vision['top1_pred']

# Calculate the confusion matrix
cm = confusion_matrix(labels, top1_preds)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
modality = 'vision'
vision_ckpt = '/content/checkpoint/beam_pred_model_vision_v2'
model_vision = get_model(modality, num_classes=65)
model_vision = model_vision.to(device)

best_model_path = vision_ckpt  # This should be the path where the best model is saved
model_vision.load_state_dict(torch.load(best_model_path))
model_vision.to(device)  # Ensure model is on the correct device

model_vision.eval()

train_scenario_nums = [1, 2, 3]  # Scenarios 1, 2, and 3 will be used for training
test_scenario_nums = [1, 2, 3]      # Scenarios 4 and 5 will be used for testing

# Define the percentage of data to be used from each training scenario
percentages = [40, 40, 40]  # Use 40% of Scenario 1, 40% of Scenario 2, and 40% of Scenario 3

# Run the function
train_df_vision, val_df_vision, test_df_vision = combine_shuffle_datasets(train_scenario_nums, test_scenario_nums, modality, percentages)

val_batch_size = 1
num_workers = 2

test_dataset = CustomDataset(dataframe=test_df_vision, modality=modality, transform=test_transforms)

test_loader = DataLoader(test_dataset,
                        batch_size=val_batch_size,
                        shuffle=False,
                        num_workers=num_workers)




_, _, _, test_results_vision = validate(model_vision, test_loader, device, modality)

# Assuming `results` is returned from `validate`
labels = test_results_vision['labels']
top1_preds = test_results_vision['top1_pred']

# Calculate the confusion matrix
cm = confusion_matrix(labels, top1_preds)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# # Transfer Learning Overview
# **Transfer learning** is a powerful machine learning technique that leverages knowledge gained from one problem to solve related but distinct problems. It's particularly useful when you have limited data for a new task, but access to a related task with an abundance of data.
#
# In practice, transfer learning typically involves taking a model trained on a large dataset and fine-tuning it on a smaller, specific dataset. This approach is prevalent in deep learning, especially in domains like image recognition and natural language processing, where pretrained models like ResNet for images or BERT for text are adapted to new tasks.
#
# **Key Benefits:**
#
# **Efficiency:** Speeds up the time to train a model as the need for training from scratch is eliminated.
#
# **Performance:** Often achieves higher performance, especially in tasks where the data is scarce or not diverse enough.
#
# **Steps in Transfer Learning:**
#
# *   **Select a Pretrained Model:** Choose a model trained on a large dataset that is similar to your new task.
# *   **Feature Extraction:** Use the pretrained model to transform new data into a better feature space.
# *   **Fine-Tuning:** Optionally, continue training the model on the new data to adapt the model weights better to the specific task.
#
# This methodology allows for the rapid deployment of robust models across various tasks, significantly cutting down on development time and computational resources.

# %%
modality = 'vision'
vision_ckpt = '/content/checkpoint/beam_pred_model_vision_v2'
model_vision = get_model(modality, num_classes=65)
model_vision = model_vision.to(device)

best_model_path = vision_ckpt  # This should be the path where the best model is saved
model_vision.load_state_dict(torch.load(best_model_path))
model_vision.to(device)  # Ensure model is on the correct device

# %%
modality = 'vision'

train_scenario_nums = [4]  # Scenarios 1, 2, and 3 will be used for training
test_scenario_nums = [4]      # Scenarios 4 and 5 will be used for testing

# Define the percentage of data to be used from each training scenario
percentages = [100]  # Use 20% of Scenario 4

# Run the function
train_df_s4, val_df_s4, test_df_s4 = combine_shuffle_datasets(train_scenario_nums, test_scenario_nums, modality, percentages)

val_batch_size = 1
num_workers = 2

test_dataset = CustomDataset(dataframe=test_df_s4, modality=modality, transform=test_transforms)

test_loader = DataLoader(test_dataset,
                        batch_size=val_batch_size,
                        shuffle=False,
                        num_workers=num_workers)




_, _, _, test_results_s4 = validate(model_vision, test_loader, device, modality)

# Assuming `results` is returned from `validate`
labels = test_results_s4['labels']
top1_preds = test_results_s4['top1_pred']

# Calculate the confusion matrix
cm = confusion_matrix(labels, top1_preds)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# **Training with a pre-trained model**
#
# Motivation: Site-Specific Training vs. General Training

# %%
def main_training_loop_w_pre_trained_model(model, train_df, val_df, test_df, device, modality, ckpt_name):

    #model = get_model(modality, num_classes=65)
    #model = model.to(device)


    print(pwd)

    train_df.to_csv(f'{pwd}/train.csv', index=False)
    val_df.to_csv(f'{pwd}/val.csv', index=False)
    test_df.to_csv(f'{pwd}/test.csv', index=False)

    # Set the batch sizes and number of workers
    batch_size = 64
    val_batch_size = 1
    num_workers = 2  # Adjust based on the capabilities of your machine

    lr = 1e-4
    decay = 1e-4


    # Create dataset instances for each DataFrame
    train_dataset = CustomDataset(dataframe=train_df, modality=modality, transform=train_transforms)
    val_dataset = CustomDataset(dataframe=val_df, modality=modality, transform=test_transforms)
    test_dataset = CustomDataset(dataframe=test_df, modality=modality, transform=test_transforms)

    # Set up the DataLoader for each dataset
    train_loader = DataLoader(train_dataset,
                              batch_size=batch_size,
                              shuffle=True,  # Shuffle for training to randomize input
                              num_workers=num_workers)

    val_loader = DataLoader(val_dataset,
                            batch_size=val_batch_size,
                            shuffle=False,  # No need to shuffle validation and test data
                            num_workers=num_workers)

    test_loader = DataLoader(test_dataset,
                            batch_size=val_batch_size,
                            shuffle=False,
                            num_workers=num_workers)


    criterion = nn.CrossEntropyLoss()
    opt = optimizer.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
    if modality == 'position':
        scheduler = optimizer.lr_scheduler.MultiStepLR(opt, milestones=[20, 40], gamma=0.1)
        num_epochs = 50
    else:
        scheduler = optimizer.lr_scheduler.MultiStepLR(opt, milestones=[4, 8], gamma=0.1)
        num_epochs = 10

    best_accuracy = 0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch + 1}')
        train(model, train_loader, criterion, opt, device, modality)
        accuracy, _, _, results = validate(model, val_loader, device, modality)
        log_and_save_results(results, save_directory, epoch)

        print("current acc", accuracy)
        print("best acc", best_accuracy)
        if accuracy > best_accuracy:
            print("Saving the best model")
            #net_name = checkpoint_directory  + '/' +  f'beam_pred_model_{modality}_transfer_learning'
            net_name = checkpoint_directory  + '/' +  ckpt_name
            torch.save(model.state_dict(), net_name)
            best_accuracy =  accuracy
        print("updated best acc", best_accuracy)

        scheduler.step()



    # Load the best checkpoint
    # Assuming the best model's name is preserved in `net_name`, load the best model
    best_model_path = net_name  # This should be the path where the best model is saved
    model.load_state_dict(torch.load(best_model_path))
    model.to(device)  # Ensure model is on the correct device

    print("Model accuracy on the test set")

    # Optionally, evaluate the model to confirm it's loaded correctly and check performance
    model.eval()
    test_accuracy, _, _, test_results = validate(model, val_loader, device, modality)
    #print(f'Loaded Model Accuracy: {accuracy}')
    return model, test_results

# %%
modality = 'vision'
ckpt_name = f'beam_pred_model_{modality}_transfer_learning'
_, results_s4 = main_training_loop_w_pre_trained_model(model_vision, train_df_s4, val_df_s4, test_df_s4, device, modality, ckpt_name)

# Assuming `results` is returned from `validate`
labels = results_s4['labels']
top1_preds = results_s4['top1_pred']

# Calculate the confusion matrix
cm = confusion_matrix(labels, top1_preds)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
modality = 'vision'
tf_vision_ckpt = '/content/checkpoint/beam_pred_model_vision_transfer_learning'
model_vision_tf = get_model(modality, num_classes=65)
model_vision_tf = model_vision_tf.to(device)

best_model_path = tf_vision_ckpt  # This should be the path where the best model is saved
model_vision_tf.load_state_dict(torch.load(best_model_path))
model_vision_tf.to(device)  # Ensure model is on the correct device

model_vision_tf.eval()


val_batch_size = 1
num_workers = 2

test_dataset = CustomDataset(dataframe=test_df_s4, modality=modality, transform=test_transforms)

test_loader = DataLoader(test_dataset,
                        batch_size=val_batch_size,
                        shuffle=False,
                        num_workers=num_workers)




_, _, _, test_results_s4 = validate(model_vision_tf, test_loader, device, modality)

# Assuming `results` is returned from `validate`
labels = test_results_s4['labels']
top1_preds = test_results_s4['top1_pred']

# Calculate the confusion matrix
cm = confusion_matrix(labels, top1_preds)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# **How much data do we need?**

# %%
train_scenario_nums = [4]  # Scenarios 1, 2, and 3 will be used for training
test_scenario_nums = [4]      # Scenarios 4 and 5 will be used for testing

# Define the percentage of data to be used from each training scenario
percentages = [40]  # Use 40% of Scenario 4

# Run the function
train_df_s4, val_df_s4, test_df_s4 = combine_shuffle_datasets(train_scenario_nums, test_scenario_nums, modality, percentages)

modality = 'vision'
ckpt_name = f'beam_pred_model_{modality}_transfer_learning_partial_dataset'
_, results_s4 = main_training_loop_w_pre_trained_model(model_vision, train_df_s4, val_df_s4, test_df_s4, device, modality, ckpt_name)

# Assuming `results` is returned from `validate`
labels = results_s4['labels']
top1_preds = results_s4['top1_pred']

# Calculate the confusion matrix
cm = confusion_matrix(labels, top1_preds)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
modality = 'vision'
tf_pd_vision_ckpt = '/content/checkpoint/beam_pred_model_vision_transfer_learning_partial_dataset'
model_vision_tf_pd = get_model(modality, num_classes=65)
model_vision_tf_pd = model_vision_tf_pd.to(device)

best_model_path = tf_pd_vision_ckpt  # This should be the path where the best model is saved
model_vision_tf_pd.load_state_dict(torch.load(best_model_path))
model_vision_tf_pd.to(device)  # Ensure model is on the correct device

model_vision_tf_pd.eval()


val_batch_size = 1
num_workers = 2

test_dataset = CustomDataset(dataframe=test_df_s4, modality=modality, transform=test_transforms)

test_loader = DataLoader(test_dataset,
                        batch_size=val_batch_size,
                        shuffle=False,
                        num_workers=num_workers)




_, _, _, test_results_s4 = validate(model_vision_tf_pd, test_loader, device, modality)

# Assuming `results` is returned from `validate`
labels = test_results_s4['labels']
top1_preds = test_results_s4['top1_pred']

# Calculate the confusion matrix
cm = confusion_matrix(labels, top1_preds)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
